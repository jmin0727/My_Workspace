# %%
mylist = [1, 2, 3, "가", "나"]
mylist
# Out:
# [1, 2, 3, '가', '나']

# %%
mytuple = (1, 2, 3, "일", "이")
mytuple
# Out:
# (1, 2, 3, '일', '이')

# %%
mydict = {"등수":3, "성별":"여자", "등급":"우수"}
mydict
# Out:
# {'등수': 3, '성별': '여자', '등급': '우수'}

# %% [markdown]
# ### **8/12**

# %%
mylist[3]
# Out:
# '가'

# %%
mytuple[2]
# Out:
# 3

# %%
mydict["성별"]
# Out:
# '여자'

# %%
mydict.keys()
# Out:
# dict_keys(['등수', '성별', '등급'])

# %%
mydict.values()
# Out:
# dict_values([3, '여자', '우수'])

# %%
mylist[0:4]
# Out:
# [1, 2, 3, '가']

# %%
mylist[3] = "다"
mylist
# Out:
# [1, 2, 3, '다', '다']
