# %% [markdown]
# ### **이건 마크다운**
# # 이건 마크다운
# ## 이건 마크다운
# ### 이건 마크다운
# #### 이건 마크다운
# ## **이건 마크다운**
# * 1111
# - 2222

# %%
# 주석
# 입니당

# 주석
# 입니당
# 주석
# 입니당
# 주석
# 입니당

# %%
# 주석
# 입니당
# 일괄 적용은 ctrl+/

# %% [markdown]
# 위에 행 추가는 a

# %% [markdown]
# 아래 행 추가는 b

# %% [markdown]
# # **제목1**

# %%
print(2)
# Out:
# 2

# %% [markdown]
# # **제목1**

# %%
print(3)
# Out:
# 3

# %% [markdown]
# markdown

# %%
print(4)
# Out:
# 4

# %% [markdown]
# # **제목1**

# %%
print(5)
# Out:
# 5

# %% [markdown]
# makrdown

# %% [markdown]
# m 누르면 마크다운으로 바뀌는가부다

# %% [markdown]
# y를 누르면 원래 코드로

# %% [markdown]
# <font color=purple size=4> <b> <i> <u> 폰트 테스트 </b> </i> </u> </font>

# %% [markdown]
# <font color=blue size=4> 폰트 테스트 </font>
# <font color=red size=3> <b> <i> <u> 입니당 <b> <i> <u> </font>

# %% [markdown]
# <img width=150 height=100 src="https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRwit1AJmY15st3mfR8CIh4vKmH3-JB-YGU8sWrAr-FuBeKtICdogoE5tdo&s=10"> </img>

# %% [markdown]
# <a href="https://www.naver.com"> <u> 네이버 바로가기 <u> </a>

# %% [markdown]
# > 이건 설명 11
# >> 이건 설명 22

# %% [markdown]
# ---

# %% [markdown]
# <font size=4 color=orange> <b> 이건<br> <i> 줄바꿈 <i> <b> </font>

# %% [markdown]
# ![image.png](attachment:eb69321b-de05-4b3a-b4e8-28dbd518141e.png)
