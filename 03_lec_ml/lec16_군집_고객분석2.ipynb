# %% [markdown]
# ![image.png](attachment:a86fd4ba-77f6-490e-a3da-d81febc40278.png)

# %% [markdown]
# * https://www.kaggle.com/competitions/online-retail-store-20201008/data

# %% [markdown]
# ![image.png](attachment:c906f019-8351-45a0-958f-f28f661a3714.png)

# %% [markdown]
# * https://www.kaggle.com/competitions/retail-return-risk-modeling/data

# %% [markdown]
# ![image.png](attachment:d7ca05a9-ebc5-4a4b-8102-85b008b15208.png)

# %% [markdown]
# * https://www.kaggle.com/datasets/hakdevelopment/e-commerce-dataset
